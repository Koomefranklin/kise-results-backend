# %%
import pandas as pd

# %%
file = pd.read_csv('results.csv')
new_file = pd.DataFrame()
file = file.dropna()
file.head()
# Out:
#          index sex                   Name Centre  Course  101_cat1  101_cat2  \
# 0  20407101214   F      NDUTA M NDIRANGU    KISE    9101        80        89
# 1  20407101215   F  MURITU RUTH WAITHIRA    KISE    9101        76        78
# 2  20407101216   F      NAKITARE HELLEN     KISE    9101        88        85
# 3  20407101217   F   OLOO NANCY ACHIENG'    KISE    9101        78        73
# 4  20407101218   F    NJUE FAITH WANYAGA    KISE    9101        86        88
#
#    102_cat1  102_cat2  103_cat1  103_cat2  104_cat1  104_cat2  \
# 0        74        88        82        74        90        90
# 1        81        77        76        79        78        79
# 2        87        84        90        90        74        88
# 3        71        72        85        81        77        75
# 4        89        88        71        84        90        88
#
#                                 session
# 0  db32989c-5c31-429c-bd2b-3196743be6c8
# 1  db32989c-5c31-429c-bd2b-3196743be6c8
# ...

# %% [markdown]
# ## User
# full_name
# sex
# role
#
# ## Student
# user
# index
# session
# centre
#
# ## Specialization
# student
# course
#
# ## Results
# specialization
# paper
# cat1
# cat2

# %%
new_file['full_name'] = file['Name']
new_file['index'] = file['index']
new_file['course'] = file['Course']
new_file['sex'] = file['sex']
new_file['centre'] = file['Centre']
new_file['session'] = file['session']
new_file['paper1'] = '9101-101'
new_file['paper1_cat1'] = file['101_cat1']
new_file['paper1_cat2'] = file['101_cat2']
new_file['paper2'] = '9101-102'
new_file['paper2_cat1'] = file['102_cat1']
new_file['paper2_cat2'] = file['102_cat2']
new_file['paper3'] = '9101-103'
new_file['paper3_cat1'] = file['103_cat1']
new_file['paper3_cat2'] = file['103_cat2']
new_file['paper4'] = '9101-104'
new_file['paper4_cat1'] = file['104_cat1']
new_file['paper4_cat2'] = file['104_cat2']

dictionary = new_file.to_dict(orient='records')

# %%
print(dictionary)
# Out:
# [{'full_name': 'NDUTA M NDIRANGU ', 'index': 20407101214, 'course': 9101, 'sex': 'F', 'centre': 'KISE', 'session': 'db32989c-5c31-429c-bd2b-3196743be6c8', 'paper1': '9101-101', 'paper1_cat1': 80, 'paper1_cat2': 89, 'paper2': '9101-102', 'paper2_cat1': 74, 'paper2_cat2': 88, 'paper3': '9101-103', 'paper3_cat1': 82, 'paper3_cat2': 74, 'paper4': '9101-104', 'paper4_cat1': 90, 'paper4_cat2': 90}, {'full_name': 'MURITU RUTH WAITHIRA ', 'index': 20407101215, 'course': 9101, 'sex': 'F', 'centre': 'KISE', 'session': 'db32989c-5c31-429c-bd2b-3196743be6c8', 'paper1': '9101-101', 'paper1_cat1': 76, 'paper1_cat2': 78, 'paper2': '9101-102', 'paper2_cat1': 81, 'paper2_cat2': 77, 'paper3': '9101-103', 'paper3_cat1': 76, 'paper3_cat2': 79, 'paper4': '9101-104', 'paper4_cat1': 78, 'paper4_cat2': 79}, {'full_name': 'NAKITARE HELLEN  ', 'index': 20407101216, 'course': 9101, 'sex': 'F', 'centre': 'KISE', 'session': 'db32989c-5c31-429c-bd2b-3196743be6c8', 'paper1': '9101-101', 'paper1_cat1': 88, 'paper1_
# ...

# %%
file.apply(1, axis=1)
# Out:
# [{'name': 'Josephine Kisilu'}, {'name': 'Dr. Joshua Odhiambo'}, {'name': 'Grace Wanjiku Kiarie'}, {'name': 'Shibuko Ramadhani Were'}, {'name': 'Timothy G. Gakuo'}, {'name': 'Lydia Kairanya'}, {'name': 'Cornelius Mwanza'}, {'name': 'Alusiah Thaara Munyi'}, {'name': 'Moses Kaniaru   '}, {'name': 'Jane Mwendwa Kiome'}, {'name': 'Richard Rukwaro'}, {'name': 'Jane Kwamboka Nyamongo'}, {'name': 'Frasia Karungari Nyota'}, {'name': 'Irene Gachathi'}, {'name': 'Dr. Lucy Marete  '}, {'name': 'Truphena Akoth Mbeke'}, {'name': 'Margaret Makunja'}, {'name': 'Marilyn Awuor'}, {'name': 'Dr. Nelly W. Maina'}, {'name': 'Elizabeth Nelima'}, {'name': 'Daniel Mbugua Ruitururi'}, {'name': 'Eunice Kagwiria Mwiti'}, {'name': 'Margaret Akinyi Odhiambo'}, {'name': 'Lilly Masoo Lengoiboni'}, {'name': 'Elinet Nyaundi Arika'}, {'name': 'Ruth C. Rono   Lecturer'}, {'name': 'Dr. Millicent Wandia Githui '}, {'name': 'Peter Lothuron Long’ore Ag.'}, {'name': 'Mercy Chepkirui Cheruiyot'}, {'name': 'Gabriel Okoto Mala
# ...
